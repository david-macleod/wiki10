# %% [markdown]
# Creating a sample of documents to use as inputs to a classification task.

# %%
import json
from pathlib import Path
import pandas as pd

# %%
DATA_DIR = Path('../../data/wiki10')
TAGS_PATH = DATA_DIR / 'tags.json'
CLF_LABELS_PATH = DATA_DIR / 'clf0-singlelabel.csv'

# %%
with TAGS_PATH.open() as input_fileobj:
    tags = json.load(input_fileobj)

# %% [markdown]
# We will create a sample which should be easy to classify as a benchmark for testing. Future tests will have more diverse classes / imbalanced classes.
#
# Choosing four tag types which were "distant" from each other in our doc2vec-evaluate analysis.

# %%
targets = {'food', 'software', 'religion', 'music', 'politics', 'math'}

# %%
df = pd.DataFrame.from_dict(tags, orient='index')
df = df.loc[df.tag.isin(targets)]

# %%
df.head()
# Out:
#                                            title user_count  \
# 0012a3afc219030f26e3adb10eb5526a         Gehenna         14
# 001312da1e617115951209bcd0fe1697   Galois theory         11
# 001f7d3f2890f8f2fb3ef7601a2cacaf      Syncretism         51
# 0029a27cb935e387433556f6a54d117c   Habeas corpus         60
# 0088076ebf3cf27718ee17b5e8c2c063  Guitar effects         12
#
#                                                                                tags  \
# 0012a3afc219030f26e3adb10eb5526a                   {'religion': 0.2857142857142857}
# 001312da1e617115951209bcd0fe1697  {'math': 0.5454545454545454, 'mathematics': 0....
# 001f7d3f2890f8f2fb3ef7601a2cacaf  {'religion': 0.27450980392156865, 'philosophy'...
# 0029a27cb935e387433556f6a54d117c    {'politics': 0.2, 'words': 0.06666666666666667}
# 0088076ebf3cf27718ee17b5e8c2c063  {'music': 0.4166666666666667, 'science': 0.083...
#
#                                        tag mapped_tag
# 0012a3afc219030f26e3adb10eb5526a  religion   religion
# 001312da1e617115951209bcd0fe1697      math       math
# 001f7d3f2890f8f2fb3ef7601a2cacaf  religion   religion
# 0029a27cb935e387433556f6a54d117c  politics   politics
# 0088076ebf3cf27718ee17b5e8c2c063     music      music

# %%
df.tag.value_counts()
# Out:
# music       985
# politics    619
# religion    605
# math        449
# software    443
# food        304
# Name: tag, dtype: int64

# %% [markdown]
# As each document is multi-labelled we still may have some instances where a document may contain labels from multiple classes in our target list.
#
# The 'tag' column which we have shown is the dominant label for each document (has the highest score, ref 01_cluster_tags) and this will be our ground truth. Now we will filter out any documents that contain one or more of the other tags types in its 'tags' column (dict of all tags for that doc) so we will have no ambiguity over whether a mis-classification is in fact simply mislabelled (multi-labelled). This is to create a simple test case to benchmark our models.

# %%
df[df.apply(lambda x: len((targets - {x.tag}) & x.tags.keys()) > 0, axis=1)]
# Out:
#                                                                               title  \
# 023127c2dce678f21ea7b87dabe5cc71                                        Pete Seeger
# 0233336c1e06fa0f3fc17a83b4d7c626                                        Scorewriter
# 0344201ccd47f440016393d24960b527                                   Condorcet method
# 035e4cd56dd70a26f53e8cacecdf4871                       Home Taping Is Killing Music
# 079b1471a99c79eac5587a7c3ee7531d                                            Last.fm
# 07daff5529134e4723e595fbdea273c3                                            Rockbox
# 0988858ab4b02605d452ee7cbdd16dae                                     Voting paradox
# 09e0bdec4922049cf5c54427eb140748                             iTunes version history
# 0aa029bba46bd6ca34e4e11f519ec966                                        Fred Phelps
# 0b5f461c681d0ddaa61a0e222bca77f5                         Discrete Fourier transform
# 0dbf8657a6906208f055f39fa023ed20                                     Apple Lossless
# e7cba60d98e3ab624b7dabc84d5cff76  {'music': 0.6428571428571429, 'math': 0.071428...
# e85c1e2194e57ac6e34c10fdc363d758  {'religion': 0.30303030303030304, 'history': 0...
# e8dbf71766665145a29a3cd608604810  {'religion': 0.45454545454545453, 'security': ...
# e9309c975067e8c941103ecb49e44d26     {'music': 0.5833333333333334, 'politics': 0.5}
# eb325d9e8e72e3427fd0e8ed11f4f25d  {'software': 0.25, 'hardware': 0.2142857142857...
# ec08f4246ce9f9c6a8ee934a812c2023  {'music': 0.36363636363636365, 'people': 0.181...
# eea898196c16e11469f8b0b88767d31e  {'religion': 0.6521739130434783, 'history': 0....
# efbc0f4c811d6d7689930d1875fc6fdc  {'math': 0.20833333333333334, 'religion': 0.16...
# f11c4418e59d31c8211d2d4ddd3a4b68  {'religion': 0.35714285714285715, 'politics': ...
# f256b28a4f06d42fb71b69612e456f12  {'math': 0.5, 'algorithms': 0.0714285714285714...
# f2e55855c695a3766b5c1084c595eaa2  {'music': 0.6153846153846154, 'software': 0.46...
# f34fbba56b2a8d0dd23e4314b8be0312  {'software': 0.3333333333333333, 'music': 0.33...
# f5229e2a782987630a39d052b69020bb  {'music': 0.46218487394957986, 'programming': ...
# f572b998f6d2576c74ebcb087cd21f56  {'software': 0.37037037037037035, 'opensource'...
# f6b86299dce627295a44203398ab8920  {'music': 0.3076923076923077, 'computers': 0.1...
# f794194a98d6c14b5dc3c9b0aeb135cf  {'music': 0.2980769230769231, 'physics': 0.153...
# f8be002bef33217c1aeef593367845ec  {'politics': 0.04, 'economics': 0.04, 'food': ...
# f9094df81287a47cae4a2fb7ee17b08d  {'software': 0.39285714285714285, 'music': 0.2...
# f9133870de4c70b2fbb917c29d7f4f3d  {'software': 0.44285714285714284, 'math': 0.44...
# fa731c057b2e4a571c025a14943b858b  {'math': 0.4375, 'science': 0.1875, 'graphics'...
# fbfa6b55a403783b3a91d176210ef23d  {'religion': 0.3157894736842105, 'politics': 0...
# fd1cd0c38a09c932b3f3c995e12f703b  {'music': 0.5806451612903226, 'math': 0.322580...
# fd6b21d7952e0a03cbd86020f949f14c  {'religion': 0.26666666666666666, 'history': 0...
# fd8017f718d56d9238e063852b606232  {'music': 0.44, 'people': 0.16, 'math': 0.04, ...
# fd8b2069eddb4c952409411add8151f5  {'politics': 0.34285714285714286, 'economics':...
#
#                                        tag mapped_tag
# 023127c2dce678f21ea7b87dabe5cc71     music      music
# 0233336c1e06fa0f3fc17a83b4d7c626     music      music
# 0344201ccd47f440016393d24960b527  politics   politics
# 035e4cd56dd70a26f53e8cacecdf4871     music      music
# 079b1471a99c79eac5587a7c3ee7531d     music      music
# 07daff5529134e4723e595fbdea273c3     music      music
# 0988858ab4b02605d452ee7cbdd16dae  politics   politics
# 09e0bdec4922049cf5c54427eb140748  software         NA
# 0aa029bba46bd6ca34e4e11f519ec966  religion   religion
# 0b5f461c681d0ddaa61a0e222bca77f5      math       math
# 0dbf8657a6906208f055f39fa023ed20     music      music
# 0e06f20b78d2809e084d88fdc3ba0429     music      music
# 0e934a92d7dc961c7edabe8c10d5d930     music      music
# 0ec2b9d58ef89d0534397dca5e9731b6  religion   religion
# 0ecc3f4c2a0b50270d23c4082b68258d  religion   religion
# 0f8e55c47cf5ebd18e367dfc1cf168fd  religion   religion
# 0fd9017154e857f2177e52b3b7ca9ac4  software         NA
# 11554b475548eae74e2ced25972437bc     music      music
# 11e7c9a640fadd78c49c5588e1f7aaf5  religion   religion
# 126bcce30578c8b8b7d67d06ee047685     music      music
# 12c6433a5d437b3061edf541198a721d  religion   religion
# 13bc76dd90c08c493c58e94b0a6ded74     music      music
# 1447e98a1df85c846233a74e04b58a4b     music      music
# 14e0936eb638872ef578a54c633b141e  religion   religion
# 15aae9b8312bbef14ec37aaa0cf03e86  religion   religion
# 161d5d6792700195662d7276a54d3251  religion   religion
# 168a0eb1745a4ad47935beed86b2f1e8     music      music
# 17a508c29ad18a9ba5e440cd6c3d20ee  religion   religion
# 17edc080695818b9a31fdc9e109e6e4d     music      music
# 18d2b23f30d14815377fb3be6c6137cf  religion   religion
# ...                                    ...        ...
# e4e4b6e3686bc078e4c34c9f4ea11316      math       math
# e5bfbac51708e4ccf95b16fe7dbc5e67  politics   politics
# e634424d96e2ac28669f8d54e81b7eb7  religion   religion
# e6b18c48dc4efc8a042ef693ac396a99  religion   religion
# e799abb132ad1acf2b833747bfa879db  politics   politics
# e7cba60d98e3ab624b7dabc84d5cff76     music      music
# e85c1e2194e57ac6e34c10fdc363d758  religion   religion
# e8dbf71766665145a29a3cd608604810  religion   religion
# e9309c975067e8c941103ecb49e44d26     music      music
# eb325d9e8e72e3427fd0e8ed11f4f25d  software         NA
# ec08f4246ce9f9c6a8ee934a812c2023     music      music
# eea898196c16e11469f8b0b88767d31e  religion   religion
# efbc0f4c811d6d7689930d1875fc6fdc      math       math
# f11c4418e59d31c8211d2d4ddd3a4b68  religion   religion
# f256b28a4f06d42fb71b69612e456f12      math       math
# f2e55855c695a3766b5c1084c595eaa2     music      music
# f34fbba56b2a8d0dd23e4314b8be0312  software         NA
# f5229e2a782987630a39d052b69020bb     music      music
# f572b998f6d2576c74ebcb087cd21f56  software         NA
# f6b86299dce627295a44203398ab8920     music      music
# f794194a98d6c14b5dc3c9b0aeb135cf     music      music
# f8be002bef33217c1aeef593367845ec  politics   politics
# f9094df81287a47cae4a2fb7ee17b08d  software         NA
# f9133870de4c70b2fbb917c29d7f4f3d  software         NA
# fa731c057b2e4a571c025a14943b858b      math       math
# fbfa6b55a403783b3a91d176210ef23d  religion   religion
# fd1cd0c38a09c932b3f3c995e12f703b     music      music
# fd6b21d7952e0a03cbd86020f949f14c  religion   religion
# fd8017f718d56d9238e063852b606232     music      music
# fd8b2069eddb4c952409411add8151f5  politics   politics
#
# [251 rows x 5 columns]

# %% [markdown]
# The biggest crossover appears to be from music related software, will now exclude these records

# %%
df = df[df.apply(lambda x: len((targets - {x.tag}) & x.tags.keys()) == 0, axis=1)]

# %%
df.tag.value_counts()
# Out:
# music       894
# politics    581
# religion    535
# math        428
# software    416
# food        300
# Name: tag, dtype: int64

# %% [markdown]
# Balancing classes

# %%
df = (df.groupby('tag')
        .apply(lambda x: x.sample(300, random_state=0))
        .reset_index(level=0, drop=True))

# %%
df.tag.value_counts()
# Out:
# politics    300
# math        300
# religion    300
# food        300
# music       300
# software    300
# Name: tag, dtype: int64

# %%
df.to_csv(CLF_LABELS_PATH, index=True, index_label='id', columns=['tag'])
