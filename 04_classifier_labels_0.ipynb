# %% [markdown]
# Creating a sample of documents to use as inputs to a classification task.

# %%
import json
from pathlib import Path
import pandas as pd

# %%
DATA_DIR = Path('../../data/wiki10')
TAGS_PATH = DATA_DIR / 'tags.json'
CLF_LABELS_PATH = DATA_DIR / 'clf0-singlelabel.csv'

# %%
with TAGS_PATH.open() as input_fileobj:
    tags = json.load(input_fileobj)

# %% [markdown]
# We will create a sample which should be easy to classify as a benchmark for testing. Future tests will have more diverse classes / imbalanced classes.
#
# Choosing four tag types which were "distant" from each other in our doc2vec-evaluate analysis.

# %%
targets = {'food', 'software', 'religion', 'music'}

# %%
df = pd.DataFrame.from_dict(tags, orient='index').loc[df.tag.isin(targets)]

# %%
df.head()
# Out:
#                                                     title user_count  \
# 0001f7867e0d59fa2797608d85fb35ac              Advergaming         31
# 00071c1d56e4601dee50016d95af90fe             Likert scale         93
# 000e9edf0163688ef62a4592546109fb  Technical communication         13
# 0012a3afc219030f26e3adb10eb5526a                  Gehenna         14
# 001312da1e617115951209bcd0fe1697            Galois theory         11
#
#                                                                                tags  \
# 0001f7867e0d59fa2797608d85fb35ac  {'games': 0.3225806451612903, 'web': 0.1290322...
# 00071c1d56e4601dee50016d95af90fe  {'statistics': 0.44086021505376344, 'psycholog...
# 000e9edf0163688ef62a4592546109fb  {'writing': 0.07692307692307693, 'management':...
# 0012a3afc219030f26e3adb10eb5526a                   {'religion': 0.2857142857142857}
# 001312da1e617115951209bcd0fe1697  {'math': 0.5454545454545454, 'mathematics': 0....
#
#                                          tag  mapped_tag
# 0001f7867e0d59fa2797608d85fb35ac       games        game
# 00071c1d56e4601dee50016d95af90fe  statistics        math
# 000e9edf0163688ef62a4592546109fb     writing  literature
# 0012a3afc219030f26e3adb10eb5526a    religion    religion
# 001312da1e617115951209bcd0fe1697        math        math

# %%
df.tag.value_counts()
# Out:
# music       985
# religion    605
# software    443
# food        304
# Name: tag, dtype: int64

# %% [markdown]
# As each document is multi-labelled we still may have some instances where a document may contain labels from multiple classes in our target list.
#
# The 'tag' column which we have shown is the dominant label for each document (has the highest score, ref 01_cluster_tags) and this will be our ground truth. Now we will filter out any documents that contain one or more of the other tags types in its 'tags' column (dict of all tags for that doc) so we will have no ambiguity over whether a mis-classification is in fact simply mislabelled (multi-labelled). This is to create a simple test case to benchmark our models.

# %%
df[df.apply(lambda x: len((targets - {x.tag}) & x.tags.keys()) > 0, axis=1)]
# Out:
#                                                                     title  \
# 0233336c1e06fa0f3fc17a83b4d7c626                              Scorewriter
# 079b1471a99c79eac5587a7c3ee7531d                                  Last.fm
# 07daff5529134e4723e595fbdea273c3                                  Rockbox
# 09e0bdec4922049cf5c54427eb140748                   iTunes version history
# 0dbf8657a6906208f055f39fa023ed20                           Apple Lossless
# 0e06f20b78d2809e084d88fdc3ba0429                                Logic Pro
# 0e934a92d7dc961c7edabe8c10d5d930                                 LimeWire
# 0ecc3f4c2a0b50270d23c4082b68258d                                 Milarepa
# 11554b475548eae74e2ced25972437bc                             Cantillation
# 126bcce30578c8b8b7d67d06ee047685                                  Demeter
# 12c6433a5d437b3061edf541198a721d                                   Orisha
# 13bc76dd90c08c493c58e94b0a6ded74                              MusicBrainz
# 17edc080695818b9a31fdc9e109e6e4d                                   Winamp
# 1a345c38dc65f23f2b75106735fae139                              Backmasking
# 1c271243c8d3b5f0ca53e2f2a6aab6b0                      Hydrogen (software)
# 25dccc78410a9939d5240ebfe8261848                             Jeskola Buzz
# 2862ca09b5adeaed10bef975b3da64c9                                  Tritone
# 2e218d7914b5346910330aa142425579                                  Tracker
# 3234eee94b988bf5a4939dc4dcef6df5                                     Lame
# 36728138baed49de0c8575a1bd1dd4d5                               Cover Flow
# 373a3251d4c1c410c74226faed3ca176                                   Sufism
# 3d7ea3c7a0d7535977880b5fe5885a6d                                 Ram Dass
# 3e1ec6cd7211e357045560017cc78897                                  Jainism
# 4050ed39af818e75fa51097ba6883e40             Sampler (musical instrument)
# 46c37b1b098a90ec5817a02507fb3ce1  Comparison of file sharing applications
# 50a3b8fd9813719658eb981470abc004                               Tag editor
# 518a4c085a3a3f9b295f5509144e3704                          Music sequencer
# 5a5faa380fffb8cc14c1a95a4a925a56                               foobar2000
# 60a07a3397a3d27cf7a9c068f429f6b7                               Rosegarden
# 6120f8578412f663f5abbb7b74b55247            Digital Audio Access Protocol
# ...                                                                   ...
# ab4a8f5dc154320203baadca7cab91be                                   iTunes
# abce1da9c5b3a00c2194a6094bfda3d6                                   Vorbis
# acc34ca1d836591bcaf742e44afe402b                           Glitch (music)
# acc7ccbc1bccdd38f3cc683bd2424397       And did those feet in ancient time
# ae7e35d67a3e92f7a6dc1deb72924a22                     Acoustic fingerprint
# b28436e06b03a4783025631fbf4a0edb                                John Frum
# ba78c1255e52ffca7885e47814eddcf2                              Replay Gain
# bfbdab60113e16a982f8a82908970963                        OpenSound Control
# c26a72884ec57b695648dd054331052f                                FL Studio
# c29890a81a9e83a2844744820204cf59                          Record producer
# c4e05161b4d2f8c35c5ff537495bca4e                               Prometheus
# c5e19237feea6b95097a1a0fc78398cc                Digital rights management
# ca5b0beb39e37fd5f0e81340113b4bb5                                 Audacity
# caa5ab0683bc7aa7a0cceb877592bfc2                    Voyager Golden Record
# cb7f4ea95ae4d5b7288cc55b267a5f6d                Digital audio workstation
# ceb4881ea306e70d5abe27f9db6a79f2                                 Vocaloid
# cec60f77f3692741a3a9cce2d19f42b6                Virtual Studio Technology
# d33336f12df02f691731e5c6ca2e00d3                                  Orpheus
# d48c56550a2570d1b867909898833141                 Ardour (audio processor)
# de62e3dcc477ad00375419e586583715                              Syd Barrett
# e0c6d23257943a73bf45aaec3618f7ff                                Dies Irae
# e0fb99fb914a388458b0787496f377c2                               Meher Baba
# e8dbf71766665145a29a3cd608604810                                    Satan
# f2e55855c695a3766b5c1084c595eaa2                             Ableton Live
# f34fbba56b2a8d0dd23e4314b8be0312                         Exact Audio Copy
# f5229e2a782987630a39d052b69020bb                                Pure Data
# f572b998f6d2576c74ebcb087cd21f56                                UltraStar
# f6b86299dce627295a44203398ab8920                    Cue sheet (computing)
# f9094df81287a47cae4a2fb7ee17b08d                                     LAME
# fd6b21d7952e0a03cbd86020f949f14c                                Jim Jones
#
#                                  user_count  \
# 0233336c1e06fa0f3fc17a83b4d7c626         12
# b28436e06b03a4783025631fbf4a0edb  {'religion': 0.6153846153846154, 'culture': 0....
# ba78c1255e52ffca7885e47814eddcf2  {'music': 0.5789473684210527, 'software': 0.47...
# bfbdab60113e16a982f8a82908970963  {'music': 0.3333333333333333, 'programming': 0...
# c26a72884ec57b695648dd054331052f                    {'music': 0.5, 'software': 0.3}
# c29890a81a9e83a2844744820204cf59  {'music': 0.2727272727272727, 'software': 0.18...
# c4e05161b4d2f8c35c5ff537495bca4e  {'religion': 0.07142857142857142, 'music': 0.0...
# c5e19237feea6b95097a1a0fc78398cc  {'music': 0.11864406779661017, 'security': 0.1...
# ca5b0beb39e37fd5f0e81340113b4bb5  {'music': 0.2564102564102564, 'software': 0.23...
# caa5ab0683bc7aa7a0cceb877592bfc2  {'music': 0.29411764705882354, 'history': 0.22...
# cb7f4ea95ae4d5b7288cc55b267a5f6d  {'music': 0.4166666666666667, 'software': 0.18...
# ceb4881ea306e70d5abe27f9db6a79f2  {'music': 0.35714285714285715, 'software': 0.2...
# cec60f77f3692741a3a9cce2d19f42b6  {'music': 0.2982456140350877, 'software': 0.14...
# d33336f12df02f691731e5c6ca2e00d3  {'religion': 0.15789473684210525, 'reading': 0...
# d48c56550a2570d1b867909898833141  {'software': 0.29411764705882354, 'opensource'...
# de62e3dcc477ad00375419e586583715  {'music': 0.2777777777777778, 'people': 0.1111...
# e0c6d23257943a73bf45aaec3618f7ff   {'music': 0.48, 'religion': 0.32, 'words': 0.08}
# e0fb99fb914a388458b0787496f377c2  {'religion': 0.3333333333333333, 'philosophy':...
# e8dbf71766665145a29a3cd608604810  {'religion': 0.45454545454545453, 'security': ...
# f2e55855c695a3766b5c1084c595eaa2  {'music': 0.6153846153846154, 'software': 0.46...
# f34fbba56b2a8d0dd23e4314b8be0312  {'software': 0.3333333333333333, 'music': 0.33...
# f5229e2a782987630a39d052b69020bb  {'music': 0.46218487394957986, 'programming': ...
# f572b998f6d2576c74ebcb087cd21f56  {'software': 0.37037037037037035, 'opensource'...
# f6b86299dce627295a44203398ab8920  {'music': 0.3076923076923077, 'computers': 0.1...
# f9094df81287a47cae4a2fb7ee17b08d  {'software': 0.39285714285714285, 'music': 0.2...
# fd6b21d7952e0a03cbd86020f949f14c  {'religion': 0.26666666666666666, 'history': 0...
#
#                                        tag mapped_tag
# 0233336c1e06fa0f3fc17a83b4d7c626     music      music
# 079b1471a99c79eac5587a7c3ee7531d     music      music
# 07daff5529134e4723e595fbdea273c3     music      music
# 09e0bdec4922049cf5c54427eb140748  software         NA
# 0dbf8657a6906208f055f39fa023ed20     music      music
# 0e06f20b78d2809e084d88fdc3ba0429     music      music
# 0e934a92d7dc961c7edabe8c10d5d930     music      music
# 0ecc3f4c2a0b50270d23c4082b68258d  religion   religion
# 11554b475548eae74e2ced25972437bc     music      music
# 126bcce30578c8b8b7d67d06ee047685     music      music
# 12c6433a5d437b3061edf541198a721d  religion   religion
# 13bc76dd90c08c493c58e94b0a6ded74     music      music
# 17edc080695818b9a31fdc9e109e6e4d     music      music
# 1a345c38dc65f23f2b75106735fae139     music      music
# 1c271243c8d3b5f0ca53e2f2a6aab6b0     music      music
# 25dccc78410a9939d5240ebfe8261848     music      music
# 2862ca09b5adeaed10bef975b3da64c9     music      music
# 2e218d7914b5346910330aa142425579  software         NA
# 3234eee94b988bf5a4939dc4dcef6df5  software         NA
# 36728138baed49de0c8575a1bd1dd4d5  software         NA
# 373a3251d4c1c410c74226faed3ca176  religion   religion
# 3d7ea3c7a0d7535977880b5fe5885a6d  religion   religion
# 3e1ec6cd7211e357045560017cc78897  religion   religion
# 4050ed39af818e75fa51097ba6883e40     music      music
# 46c37b1b098a90ec5817a02507fb3ce1  software         NA
# 50a3b8fd9813719658eb981470abc004  software         NA
# 518a4c085a3a3f9b295f5509144e3704     music      music
# 5a5faa380fffb8cc14c1a95a4a925a56     music      music
# 60a07a3397a3d27cf7a9c068f429f6b7     music      music
# 6120f8578412f663f5abbb7b74b55247     music      music
# ...                                    ...        ...
# ab4a8f5dc154320203baadca7cab91be     music      music
# abce1da9c5b3a00c2194a6094bfda3d6     music      music
# acc34ca1d836591bcaf742e44afe402b     music      music
# acc7ccbc1bccdd38f3cc683bd2424397     music      music
# ae7e35d67a3e92f7a6dc1deb72924a22     music      music
# b28436e06b03a4783025631fbf4a0edb  religion   religion
# ba78c1255e52ffca7885e47814eddcf2     music      music
# bfbdab60113e16a982f8a82908970963     music      music
# c26a72884ec57b695648dd054331052f     music      music
# c29890a81a9e83a2844744820204cf59     music      music
# c4e05161b4d2f8c35c5ff537495bca4e  religion   religion
# c5e19237feea6b95097a1a0fc78398cc     music      music
# ca5b0beb39e37fd5f0e81340113b4bb5     music      music
# caa5ab0683bc7aa7a0cceb877592bfc2     music      music
# cb7f4ea95ae4d5b7288cc55b267a5f6d     music      music
# ceb4881ea306e70d5abe27f9db6a79f2     music      music
# cec60f77f3692741a3a9cce2d19f42b6     music      music
# d33336f12df02f691731e5c6ca2e00d3  religion   religion
# d48c56550a2570d1b867909898833141  software         NA
# de62e3dcc477ad00375419e586583715     music      music
# e0c6d23257943a73bf45aaec3618f7ff     music      music
# e0fb99fb914a388458b0787496f377c2  religion   religion
# e8dbf71766665145a29a3cd608604810  religion   religion
# f2e55855c695a3766b5c1084c595eaa2     music      music
# f34fbba56b2a8d0dd23e4314b8be0312  software         NA
# f5229e2a782987630a39d052b69020bb     music      music
# f572b998f6d2576c74ebcb087cd21f56  software         NA
# f6b86299dce627295a44203398ab8920     music      music
# f9094df81287a47cae4a2fb7ee17b08d  software         NA
# fd6b21d7952e0a03cbd86020f949f14c  religion   religion
#
# [86 rows x 5 columns]

# %% [markdown]
# The biggest crossover appears to be from music related software, will now exclude these records

# %%
df = df[df.apply(lambda x: len((targets - {x.tag}) & x.tags.keys()) == 0, axis=1)]

# %%
df.tag.value_counts()
# Out:
# music       931
# religion    588
# software    429
# food        303
# Name: tag, dtype: int64

# %% [markdown]
# Balancing classes

# %%
df = (df.groupby('tag')
        .apply(lambda x: x.sample(300))
        .reset_index(level=0, drop=True))

# %%
df.tag.value_counts()
# Out:
# food        300
# software    300
# religion    300
# music       300
# Name: tag, dtype: int64

# %%
df.to_csv(CLF_LABELS_PATH, index=True, index_label='id', columns=['tag'])
